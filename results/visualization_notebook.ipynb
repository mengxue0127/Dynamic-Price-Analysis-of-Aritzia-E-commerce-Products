# %% [markdown]
# # Aritzia Price Analysis - Visualization Notebook

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display

# Setup
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Load Processed Data

# %%
# Load time series data
df = pd.read_csv('../data/processed/price_time_series.csv', parse_dates=['date'])
print(f"Loaded {len(df)} observations")
df.head()

# %%
# Load category analysis
category_df = pd.read_csv('../data/processed/category_analysis.csv')
category_df

# %% [markdown]
# ## Visualization 1: Daily Price Trajectory
#
# This visualization shows how average prices and discounts changed over the 10-day collection period.

# %%
display(Image(filename='../results/daily_price_trajectory.png', width=800))

# %% [markdown]
# ## Visualization 2: Category Discount Comparison
#
# Comparing average discounts and discount frequency across product categories.

# %%
display(Image(filename='../results/category_discounts.png', width=900))

# %% [markdown]
# ## Visualization 3: Price and Discount Distribution
#
# Box plots showing the distribution of prices and discounts by category.

# %%
display(Image(filename='../results/distribution_boxplots.png', width=900))

# %% [markdown]
# ## Visualization 4: Category-Day Heatmap
#
# Heatmap showing discount patterns across categories and days.

# %%
display(Image(filename='../results/category_heatmap.png', width=900))

# %% [markdown]
# ## Visualization 5: Price vs. Discount Scatter Plot
#
# Examining the relationship between original price and discount percentage.

# %%
display(Image(filename='../results/price_vs_discount_scatter.png', width=800))

# %% [markdown]
# ## Visualization 6: Correlation Matrix
#
# Correlation between price-related variables.

# %%
display(Image(filename='../results/correlation_heatmap.png', width=600))

# %% [markdown]
# ## Visualization 7: Discount Tier Distribution
#
# Distribution of discount tiers overall and by category.

# %%
display(Image(filename='../results/discount_tier_distribution.png', width=900))

# %% [markdown]
# ## Key Findings Summary
#
# 1. **Most Frequently Discounted Category**: Dresses (61.1% of products on sale)
# 2. **Highest Average Discount**: Tops (14.4%)
# 3. **Best Category for Savings**: Outerwear ($35.77 average savings)
# 4. **Discount Trend**: Slight decreasing trend over the collection period
# 5. **Best Day for Discounts**: Thursday (12.9% average discount)
